# %% [markdown]
# <a href="https://colab.research.google.com/github/kimmjen/Colab/blob/master/FinanceDataReader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  차트 설정
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = 'nanummyeongjo'
plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams["axes.grid"] = True

# %%
# %%html
# <style>
#     table { display: inline-block }
#     .rendered_html td, .rendered_html th { text-align: left; }
# </style>
# Out:
# <style>
#     table { display: inline-block }
#     .rendered_html td, .rendered_html th { text-align: left; }
# </style>

# %%
pip install -U finance-datareader

# %%
import FinanceDataReader as fdr

# 한국거래소 상장종목 전체
df_krx = fdr.StockListing('KRX')
df_krx.head()
# Out:
#    Symbol  Market  ...                       HomePage Region
# 0  060310  KOSDAQ  ...           http://www.3sref.com  서울특별시
# 1  095570   KOSPI  ...         http://www.ajnet.co.kr  서울특별시
# 2  006840   KOSPI  ...  http://www.aekyunggroup.co.kr  서울특별시
# 3  054620  KOSDAQ  ...   http://www.apsholdings.co.kr    경기도
# 4  265520  KOSDAQ  ...     http://www.apsystems.co.kr    경기도
#
# [5 rows x 10 columns]

# %%
len(df_krx)
# Out:
# 2553

# %%
import FinanceDataReader as fdr

# 삼성전자, 2019
df = fdr.DataReader('005930', '2019')
df.head(10)
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2019-01-02  39400  39400  38550  38750   7847664  0.001292
# 2019-01-03  38300  38550  37450  37600  12471493 -0.029677
# 2019-01-04  37450  37600  36850  37450  14108958 -0.003989
# 2019-01-07  38000  38900  37800  38750  12748997  0.034713
# 2019-01-08  38000  39200  37950  38100  12756554 -0.016774
# 2019-01-09  38650  39600  38300  39600  17452708  0.039370
# 2019-01-10  40000  40150  39600  39800  14731699  0.005051
# 2019-01-11  40350  40550  39950  40500  11661063  0.017588
# 2019-01-14  40450  40700  39850  40050  11984996 -0.011111
# 2019-01-15  40050  41100  39850  41100  11492756  0.026217

# %%
import FinanceDataReader as fdr

# 카카오, 2019
df = fdr.DataReader('035720', '2019')
df.head(10)
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2019-01-02  103500  105000  101500  102000  173462 -0.009709
# 2019-01-03  102500  105500  100500  102500  293989  0.004902
# 2019-01-04  102000  104000  101500  103500  251728  0.009756
# 2019-01-07  105000  107000  102000  103000  378153 -0.004831
# 2019-01-08  102500  103000   99500   99900  450462 -0.030097
# 2019-01-09  100500  102500  100000  102000  357096  0.021021
# 2019-01-10  101000  103000  100500  101000  291573 -0.009804
# 2019-01-11  101000  103500  101000  102000  180561  0.009901
# 2019-01-14  102000  102000   99800  100000  243305 -0.019608
# 2019-01-15  100000  102500   99500   99900  381581 -0.001000

# %%
import FinanceDataReader as fdr

# 삼성전자, 2017년~현재

df = fdr.DataReader('005930', '2017')
df['Close'].plot()

# %%
import FinanceDataReader as fdr

# 카커오, 2017년~현재

df = fdr.DataReader('035720', '2017')
df['Close'].plot()

# %%
import FinanceDataReader as fdr

# KS11 (KOSPI 지수), 2015년~현재
df = fdr.DataReader('KS11', '2015')
df['Close'].plot()

# %%
# 다우지수, 2015년~현재

df = fdr.DataReader('DJI', '2015')
df['Close'].plot()

# %%
import FinanceDataReader as fdr

# 원달러 환율, 1995년~현재
df = fdr.DataReader('USD/KRW', '1995')
df['Close'].plot()
